# %%
import requests

url = 'https://ds-pipeline-dspa-test-ai-fraud-detection.apps.rdlopenshiftvm.rdlabo.local/apis/v1beta1/healthz'
response = requests.get(url)
print(response.status_code)
print(response)
# Out:
# 403
# <Response [403]>

# %%
import requests

url = 'https://minio-console-test-ai-fraud-detection-minio.apps.rdlopenshiftvm.rdlabo.local'
response = requests.get(url)
print(response.status_code)
print(response)
# Out:
# 200
# <Response [200]>

# %%
from kfp import Client
import sys

host = "https://ds-pipeline-dspa-test-ai-fraud-detection.apps.rdlopenshiftvm.rdlabo.local"
namespace = "test-ai-fraud-detection"
token = "sha256~EpZi5QQRM_NJpsJ_DyVooUV_vbj__2uoNoRN5wAQi9w"
  
c = Client(host=host, namespace=namespace, existing_token=token)
e = c.list_experiments(namespace=namespace)
print(e)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/kfp/client/client.py:159: FutureWarning: This client only works with Kubeflow Pipeline v2.0.0-beta.2 and later versions.
#   warnings.warn(
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /opt/app-root/lib64/python3.9/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
# ...

# %%
from kfp import Client
import sys

host = "https://ds-pipeline-dspa-test-ai-fraud-detection.apps.rdlopenshiftvm.rdlabo.local"
namespace = "test-ai-fraud-detection"
token = "sha256~EpZi5QQRM_NJpsJ_DyVooUV_vbj__2uoNoRN5wAQi9w"
cert = "/run/secrets/kubernetes.io/serviceaccount/ca.crt"
  
c = Client(host=host, namespace=namespace, existing_token=token, ssl_ca_cert=cert)
e = c.list_experiments(namespace=namespace)
print(e)
# Out:
# {'experiments': [{'created_at': datetime.datetime(2024, 6, 11, 10, 15, 22, tzinfo=tzlocal()),
#                   'description': 'All runs created without specifying an '
#                                  'experiment will be grouped here.',
#                   'id': '04db8573-6376-4d4d-b443-3c3912a183e2',
#                   'name': 'Default',
#                   'resource_references': [{'key': {'id': None,
#                                                    'type': 'NAMESPACE'},
#                                            'name': None,
#                                            'relationship': 'OWNER'}],
#                   'storage_state': 'STORAGESTATE_AVAILABLE'}],
#  'next_page_token': None,
#  'total_size': 1}
